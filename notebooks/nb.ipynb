# %%
import duckdb
import pandas as pd
customers = pd.read_csv('/Users/subhashkotaru/Downloads/allyin-compass/data/structured/customers.csv')

# %%
# duckdb.sql("DROP TABLE customers")
duckdb.sql("SELECT * FROM customers LIMIT 10").df()
# Out:
#   customer_id              company_name   domain  risk_score  annual_revenue  \
# 0        C001         Global Pharma Inc  Biotech         7.2        45000000
# 1        C002      Energy Solutions LLC   Energy         8.5        78000000
# 2        C003              TechFin Corp  Finance         4.1       120000000
# 3        C004       Green Power Systems   Energy         6.8        34000000
# 4        C005       BioMed Research Ltd  Biotech         5.5        56000000
# 5        C006  Capital Investment Group  Finance         3.2       250000000
# 6        C007            Solar Dynamics   Energy         7.9        23000000
# 7        C008             Genomics Plus  Biotech         9.1        12000000
# 8        C009     Wealth Management Inc  Finance         2.8       180000000
# 9        C010            Wind Energy Co   Energy         5.2        89000000
#
#   compliance_status          location account_manager last_audit_date  \
# ...

# %%
orders = pd.read_csv('/Users/subhashkotaru/Downloads/allyin-compass/data/structured/orders.csv')

# %%
duckdb.sql("SELECT * FROM orders LIMIT 10").df()
# Out:
#   order_id customer_id  order_date             product_service  \
# 0     O001        C001  2024-12-01   Clinical Trial Management
# 1     O002        C002  2024-11-15       Carbon Offset Credits
# 2     O003        C003  2024-12-10    Risk Assessment Software
# 3     O004        C004  2024-10-22  Emission Monitoring System
# 4     O005        C005  2024-12-05               Lab Equipment
# 5     O006        C006  2024-11-28        Portfolio Management
# 6     O007        C007  2024-12-18    Solar Panel Installation
# 7     O008        C008  2024-09-30     Gene Sequencing Service
# 8     O009        C009  2024-12-12         Investment Advisory
# 9     O010        C010  2024-11-20    Wind Turbine Maintenance
#
#              category   amount       status compliance_required risk_flag  \
# 0   Research Services  2500000    Completed                 Yes       Low
# 1       Environmental   450000  In Progress                 Yes      High
# ...

# %%
emissions = pd.read_csv('/Users/subhashkotaru/Downloads/allyin-compass/data/structured/emissions.csv')

# %%
duckdb.sql("SELECT * FROM emissions LIMIT 10").df()
# Out:
#   facility_id customer_id             facility_name       location  \
# 0        F001        C002  Energy Solutions Plant A     Houston TX
# 1        F002        C002  Energy Solutions Plant B    Beaumont TX
# 2        F003        C004      Green Power Facility    Portland OR
# 3        F004        C004     Green Power Station 2       Salem OR
# 4        F005        C007    Solar Dynamics Factory     Phoenix AZ
# 5        F006        C010    Wind Energy Operations      Denver CO
# 6        F007        C013    Natural Gas Terminal A      Dallas TX
# 7        F008        C013    Natural Gas Terminal B  Fort Worth TX
# 8        F009        C001         Global Pharma Lab      Boston MA
# 9        F010        C005    BioMed Research Center   San Diego CA
#
#      emission_type  emission_value        unit measurement_date  \
# 0              CO2          4500.0  tons/month       2024-12-01
# 1              NOx           125.0      kg/day       2024-12-01
# ...
